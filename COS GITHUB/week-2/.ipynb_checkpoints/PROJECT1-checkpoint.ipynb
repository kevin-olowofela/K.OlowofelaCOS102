# %% [markdown]
# #C
# START
# INPUT AGE1
# INPUT AGE2
# SET NAME1=AGE1
# SET NAME2=AGE2
# SET AGESWAP=AGE1
# SET NAME1=AGE2
# SET NAME2=AGESWAP
# DISPLAY NAME1
# DISPLAY NAME2

# %% [markdown]
# #A
# START
#  SET TOTAL=0
#  INPUT NO_OF_ITEMS
# FOR I FROM NO_OF_ITEMS
#  INPUT ITEM_PRICE
#  SET TOTAL=ITEM_PRICE+TOTAL
# DISPLAY TOTAL
# IF PAYMENT SUCCESSFUL
#  PRINT PAYMENT SUCCESFUL
# ELSE
#  PRINT PAYMENT DENIED
# END IF
# PRINT THANKYOU FOR SHOPPING WITH US
# STOP

# %% [markdown]
# #A
# ![image.png](attachment:ae1783b3-941e-4f90-8ecb-136a734fcd39.png)

# %% [markdown]
# #B
# ![image.png](attachment:9a81f973-5c17-480c-86be-28f0f2e7a5a6.png)
