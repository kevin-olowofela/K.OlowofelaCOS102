# %%
girl_name=['evelyn','jessica','somto','edith','liza','madonna','waje','tola','aisha','latifa']
girl_age=[17,16,17,18,16,18,17,20,19,17]
girl_height=[5.5,6.0,5.4,5.9,5.6,5.5,6.1,6.0,5.7,5.5]
girl_scores=[80,85,70,60,76,66,87,95,50,49]
print("name age height scores")
for n,a,h,s in zip(girl_name,girl_age,girl_height,girl_scores):
   print(f"{n} {a} {h} {s}")
# Out:
# name age height scores
# evelyn 17 5.5 80
# jessica 16 6.0 85
# somto 17 5.4 70
# edith 18 5.9 60
# liza 16 5.6 76
# madonna 18 5.5 66
# waje 17 6.1 87
# tola 20 6.0 95
# aisha 19 5.7 50
# latifa 17 5.5 49

# %%
boy_name=['chinedu','liam','wale','gbenga','abiola','kola','kunle','george','thomas','wesley']
boy_age=[19,16,18,17,20,19,16,18,17,19]
boy_height=[5.7,5.9,5.8,6.1,5.4,6.1,5.4,5.8,5.7,]
boy_scores=[74,87,75,68,66,78,87,98,54,60]
print("name age height scores")
for n,a,h,s in zip(boy_name,boy_age,boy_height,boy_scores):
   print(f"{n} {a} {h} {s}")
# Out:
# name age height scores
# chinedu 19 5.7 74
# liam 16 5.9 87
# wale 18 5.8 75
# gbenga 17 6.1 68
# abiola 20 5.4 66
# kola 19 6.1 78
# kunle 16 5.4 87
# george 18 5.8 98
# thomas 17 5.7 54
