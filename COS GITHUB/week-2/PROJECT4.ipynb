# %%
print('Izifin Technology')
try:
    age=int(input('how old are you'))
    exp=int(input('how many years of experience do you have'))
    if exp>25 and age>=55:
        atr=5600000
        print('Annual tax revenue is',atr)
    elif exp>20 and age>=45:
        atr=4480000
        print('Annual tax revenue is',atr)
    elif exp>=10 and age>=35:
        atr=1500000
        print('Annual tax revenue is',atr)
    elif exp<10 and age<35:
        atr=550000
        print('Annual tax revenue is',atr)
    else:
        print('invalid details')
except Exception as e:
    print(e)
# Out:
# Izifin Technology
# how old are you three
# invalid literal for int() with base 10: 'three'
